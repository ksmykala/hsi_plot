# %% [markdown]
# # Hyperspectral data plot

# %%
import pandas as pd
from src.hsi_chart import hsi_plot
import matplotlib.pyplot as plt

# %% [markdown]
# Read sample data

# %%
df = pd.read_csv('data/sample_hsi.csv')
df.head()
# Out:
#    Unnamed: 0                                   measurement_id  group_id  \
# 0        1593  kom1_2019-09-24_0900050-kom1_2019-09-24_0900054         9
# 1        3824  kom1_2019-09-30_1200035-kom1_2019-09-30_1200039        12
# 2        7887  kom1_2019-10-23_2200075-kom1_2019-10-23_2200079        22
# 3       10499  kom1_2019-09-18_1100085-kom1_2019-09-18_1100089        11
# 4        3996  kom1_2019-10-01_0900000-kom1_2019-10-01_0900004         9
#
#          date         type  variety                        pathogen  \
# 0  2019-09-24  phytotron_1   Benito  Pseudomonas syringe pv. Tomato
# 1  2019-09-30  phytotron_1   Benito                         Control
# 2  2019-10-23  phytotron_1  Polfast            Septoria lycopersici
# 3  2019-09-18  phytotron_1   Benito          Phytophthora infestans
# 4  2019-10-01  phytotron_1   Benito  Pseudomonas syringe pv. Tomato
#
#               disease     seeding    planting  ...    2497.0    2498.0  \
# ...

# %%
fig = hsi_plot(
    df,
    title='Healthy & unhealthy',
    xlabel='wavelength [nm]',
    ylabel='reflectance',
    alpha=0.3
)

plt.show()
